# %% [markdown]
# <a href="https://colab.research.google.com/github/abel-wosula/Data-Extraction-using-Python/blob/main/Modules%20%26%20Packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction to Modules in Python
#
#
# *    Are external packets of code that extend functinality of code.
# *  Reduce time that otherwise would be used to write code.
# *   Module - a file that defines functions, classes, variables and runnable code.
# Modules are imported and referenced from other Python code.
#
# *   A Python package / library - libraries of python code - directories and subdirectories.
# *   Modular programming is a style of programming that promotes code reusability, allowing us to generate single pieces of code which can be used in multiple parts of a project – thus saving time and resources. The resulting code can be simpler to understand and maintain since components can be considered in isolation. In Python, modularisation is implemented using functions, modules, and packages.

# %%
#writing a module

txt = """
s = 'Hello'
def say_hi(name):
  print(s + ' ' + name)
class Greet:
  pass
"""

# write the above text file to a file called my_module.py
with open('./my_module.py', 'w') as fp:
  fp.write(txt)

# %%
print(txt)
# Out:
# s = 'Hello'
# def say_hi(name):
#   print(s + ' ' + name)
# class Greet:
#   pass

# %% [markdown]
# Once a module is written it can be accessed from any Python file using the import statement.
#
# import <module_name>
#
# Multiple Importing
#
# import <module_name>
# import <module_name>
# import <module_name>
#
# Chained importing
#
# import <module_name>, <module_name>, <module_name>,...
#
# The same notion applies to packages.
#
# We can import specific modules within a package by using the dot notation.

# %%
import my_module

# %%
# Objects in that module are only accessible when prefixed with the dot and module name

my_module.s
# Out:
# 'Hello'

# %%
my_module.say_hi('TeeGee')
# Out:
# Hello TeeGee

# %%
# we can also use the from keyword to import objects directly.
from my_module import s, say_hi, Greet
s
say_hi('Chibee')
Greet
# Out:
# Hello Chibee
# my_module.Greet

# %% [markdown]
# Import statement allows us to use aliases in module referencing.

# %%
import my_module as md

# %%
md.s
# Out:
# 'Hello'

# %% [markdown]
# **Try and Except Statements in Python**
#
# In Python, errors and exceptions can interrupt the execution of program. Python provides try and except blocks to handle situations like this. In case an error occurs in try-block, Python stops executing try block and jumps to exception block. These blocks let you handle the errors without crashing the program.

# %%
# Try and except statements and usage
# Basic operation

try:
  x = 3 /0
  print(x)
except:
  print("Error! A division error occured")
# Out:
# Error! A division error occured

# %% [markdown]
# **Why do we need try-except**
#
# - Prevents crashes caused by runtime errors.
# - Handles specific exceptions like division by zero, file not found, etc.
# - Improves code reliability and error tolerance.
# - Allows custom error messages and fallback logic.
# - Essential for robust, debuggable applications.
#
# **How try() works?**
#
# - First, the try clause is executed i.e. the code between try.
# - If there is no exception, then only the try clause will run, except clause is finished.
# - If any exception occurs, the try clause will be skipped and except clause will run.
# - If any exception occurs, but the except clause within the code doesn't handle it, it is passed on to the outer try statements. If the exception is left unhandled, then the execution stops.
# - A try statement can have more than one except clause
#
# **Some of the common Exception Errors**
#
# - IOError: if the file can't be opened
# KeyboardInterrupt: when an unrequired key is pressed by the user
# - ValueError: when the built-in function receives a wrong argument
# - EOFError: if End-Of-File is hit without reading any data
# - ImportError: if it is unable to find the module

# %%
# In daily implementation:
def division(x,y):
  try:
    result = x /y
    print("Yeah ! Your answer is :", result)
  except:
    print("Sorry ! You are dividing by zero ")

print(division(3 , 2 ))
print(division(3 , 0 ))
# Out:
# Yeah ! Your answer is : 1.5
# None
# Sorry ! You are dividing by zero
# None

# %% [markdown]
# **Built-in modules**
#
# - Python contains a large number of what are known as 'built-in' modules. These modules can be accessed in Python programs by simply importing them using their name preceded by the keyword import.
#
# - Each built-in module contains resources for certain system-specific functionalities such as operating system management, disk input-output, etc. Python scripts (with the .py extension) containing useful utilities are embedded within the standard library.
# - help(modules) - lists all available Python built-in modules.

# %%
# Math built in module

import math as mathematics

x = mathematics.sqrt(81)

print("The squareroot of 81 is: ", x)
# Out:
# The squareroot of 81 is:  9.0
